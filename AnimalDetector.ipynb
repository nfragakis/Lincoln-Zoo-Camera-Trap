# %%
# !pip uninstall tensorflow
# !pip install tensorflow-gpu==1.13.1 humanfriendly jsonpickle
# Out:
# Uninstalling tensorflow-2.4.1:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.4.1.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.4.1
# ...
#      |████████████████████████████████| 345.0MB 44kB/s
# ...
#      |████████████████████████████████| 92kB 11.0MB/s
# ...
#      |████████████████████████████████| 368kB 45.2MB/s
# ...
#      |████████████████████████████████| 51kB 8.1MB/s
# ...
#      |████████████████████████████████| 3.2MB 50.9MB/s
# ...
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
# ...

# %%
# !wget -O /content/megadetector_v4_1_0.pb https://lilablobssc.blob.core.windows.net/models/camera_traps/megadetector/md_v4.1.0/md_v4.1.0.pb
# Out:
# --2021-05-04 14:23:35--  https://lilablobssc.blob.core.windows.net/models/camera_traps/megadetector/md_v4.1.0/md_v4.1.0.pb
# Resolving lilablobssc.blob.core.windows.net (lilablobssc.blob.core.windows.net)... 52.239.159.84
# Connecting to lilablobssc.blob.core.windows.net (lilablobssc.blob.core.windows.net)|52.239.159.84|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 245590501 (234M) [application/octet-stream]
# Saving to: ‘/content/megadetector_v4_1_0.pb’
#
# /content/megadetect 100%[===================>] 234.21M  10.8MB/s    in 28s
#
# 2021-05-04 14:24:03 (8.41 MB/s) - ‘/content/megadetector_v4_1_0.pb’ saved [245590501/245590501]

# %%
# !git clone https://github.com/microsoft/CameraTraps
# !git clone https://github.com/microsoft/ai4eutils
# Out:
# Cloning into 'CameraTraps'...
# remote: Enumerating objects: 11501, done.
# remote: Counting objects: 100% (477/477), done.
# remote: Compressing objects: 100% (331/331), done.
# remote: Total 11501 (delta 267), reused 263 (delta 144), pack-reused 11024
# Receiving objects: 100% (11501/11501), 120.60 MiB | 13.44 MiB/s, done.
# Resolving deltas: 100% (6755/6755), done.
# Cloning into 'ai4eutils'...
# remote: Enumerating objects: 650, done.
# remote: Counting objects: 100% (231/231), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 650 (delta 139), reused 116 (delta 57), pack-reused 419
# Receiving objects: 100% (650/650), 1.33 MiB | 7.94 MiB/s, done.
# Resolving deltas: 100% (370/370), done.

# %%
# !cp /content/CameraTraps/detection/run_tf_detector_batch.py .
# !cp /content/CameraTraps/visualization/visualize_detector_output.py .

# %%
import os
os.environ['PYTHONPATH'] += ":/content/ai4eutils"
os.environ['PYTHONPATH'] += ":/content/CameraTraps"

# !echo "PYTHONPATH: $PYTHONPATH"
# Out:
# PYTHONPATH: /env/python:/content/ai4eutils:/content/CameraTraps

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#images_dir = './drive/My Drive/DePaul Research/images/D/'
images_dir = './drive/My Drive/DePaul Research/images/J/J01'

# choose a location for the output JSON file
#output_file_path = './drive/My Drive/DePaul Research/D.json'
output_file_path = './drive/My Drive/DePaul Research/J.json'

# %%
# !python run_tf_detector_batch.py megadetector_v4_1_0.pb "$images_dir" "$output_file_path" --recursive
# Out:
# Streaming output truncated to the last 5000 lines.
#  28% 1940/6936 [25:40<1:04:31,  1.29it/s]Processing image ./drive/My Drive/DePaul Research/images/J/J01/CHIL - J01-LMP1-AP18_00288.JPG
#  28% 1941/6936 [25:41<1:01:55,  1.34it/s]Processing image ./drive/My Drive/DePaul Research/images/J/J01/CHIL - J01-BBS1-JU18_00016.JPG
#  28% 1942/6936 [25:42<1:03:06,  1.32it/s]Processing image ./drive/My Drive/DePaul Research/images/J/J01/CHIL - J01-UIC1-JA18_00181.JPG
#  28% 1943/6936 [25:43<1:03:20,  1.31it/s]Processing image ./drive/My Drive/DePaul Research/images/J/J01/CHIL - J01-UIC1-JU18_00405.JPG
#  28% 1944/6936 [25:43<1:03:10,  1.32it/s]Processing image ./drive/My Drive/DePaul Research/images/J/J01/CHIL - J01-NOR1-JA18_01104.JPG
#  28% 1945/6936 [25:44<1:05:25,  1.27it/s]Processing image ./drive/My Drive/DePaul Research/images/J/J01/CHIL - J01-UIC1-JU18_00363.JPG
# ...

# %%
visualization_dir = './drive/My Drive/DePaul Research/Annotations'

# %%
# !python visualize_detector_output.py "$output_file_path" "$visualization_dir" --confidence 0.8 --images_dir "./"
# Out:
# detection_categories provided
# Detector output file contains 7476 entries.
# Starting to annotate the images...
# 100% 7476/7476 [05:12<00:00, 23.95it/s]
# Rendered detection results on 7476 images, saved to ./drive/My Drive/DePaul Research/Annotations.
